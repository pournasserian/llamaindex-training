# %% [markdown]
# ### Using tokenizer

# %%
from tiktoken._educational import *

# Train a BPE tokeniser on a small amount of text
enc = train_simple_encoding()

# Visualise how the GPT-4 encoder encodes text
enc = SimpleBytePairEncoding.from_tiktoken("cl100k_base")
enc.encode("hello world aaaaaaaaaaaa")
# Out:
# The current most common pair is b' ' + b' '
# So we made b'  ' our 257th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'  ' + b'  '
# So we made b'    ' our 258th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'  ' + b' '
# So we made b'   ' our 259th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'n'
# So we made b'in' our 260th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'e' + b'n'
# So we made b'en' our 261th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n' + b'    '
# So we made b'\n    ' our 262th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'o' + b'r'
# So we made b'or' our 263th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b't'
# So we made b' t' our 264th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'c' + b'o'
# So we made b'co' our 265th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n    ' + b'   '
# So we made b'\n       ' our 266th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b's' + b't'
# So we made b'st' our 267th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'o' + b'k'
# So we made b'ok' our 268th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ok' + b'en'
# So we made b'oken' our 269th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b't' + b'e'
# So we made b'te' our 270th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'd' + b'e'
# So we made b'de' our 271th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'p' + b'a'
# So we made b'pa' our 272th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'='
# So we made b' =' our 273th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b's'
# So we made b'is' our 274th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'w'
# So we made b' w' our 275th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'r' + b'a'
# So we made b'ra' our 276th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n' + b'   '
# So we made b'\n   ' our 277th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'in'
# So we made b' in' our 278th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'b'
# So we made b' b' our 279th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n    ' + b'    '
# So we made b'\n        ' our 280th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'or' + b'd'
# So we made b'ord' our 281th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'y' + b'te'
# So we made b'yte' our 282th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'm'
# So we made b' m' our 283th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' t' + b'oken'
# So we made b' token' our 284th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'e' + b'r'
# So we made b'er' our 285th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'"' + b'"'
# So we made b'""' our 286th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'a' + b'l'
# So we made b'al' our 287th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'r' + b'e'
# So we made b're' our 288th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ra' + b'n'
# So we made b'ran' our 289th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'yte' + b's'
# So we made b'ytes' our 290th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'co' + b'de'
# So we made b'code' our 291th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'a' + b't'
# So we made b'at' our 292th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'o' + b'n'
# So we made b'on' our 293th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'l' + b'e'
# So we made b'le' our 294th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'h' + b'e'
# So we made b'he' our 295th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'g' + b'e'
# So we made b'ge' our 296th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'in' + b'g'
# So we made b'ing' our 297th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ran' + b'k'
# So we made b'rank' our 298th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'f'
# So we made b' f' our 299th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'pa'
# So we made b' pa' our 300th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'r'
# So we made b'ir' our 301th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'st' + b'r'
# So we made b'str' our 302th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'l'
# So we made b' l' our 303th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'o' + b'u'
# So we made b'ou' our 304th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'i'
# So we made b' i' our 305th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b't' + b'oken'
# So we made b'token' our 306th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' w' + b'ord'
# So we made b' word' our 307th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'#'
# So we made b' #' our 308th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'a'
# So we made b' a' our 309th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'b' + b'ytes'
# So we made b'bytes' our 310th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'v'
# So we made b' v' our 311th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n        ' + b'   '
# So we made b'\n           ' our 312th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'er' + b'ge'
# So we made b'erge' our 313th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b's' + b'e'
# So we made b'se' our 314th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'rank' + b's'
# So we made b'ranks' our 315th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' t' + b'he'
# So we made b' the' our 316th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b're'
# So we made b' re' our 317th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'a' + b'b'
# So we made b'ab' our 318th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' f' + b'or'
# So we made b' for' our 319th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'['
# So we made b' [' our 320th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'co' + b'l'
# So we made b'col' our 321th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b']' + b')'
# So we made b'])' our 322th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'is' + b'e'
# So we made b'ise' our 323th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'en'
# So we made b' en' our 324th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'u' + b'al'
# So we made b'ual' our 325th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n        ' + b'    '
# So we made b'\n            ' our 326th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' m' + b'erge'
# So we made b' merge' our 327th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'p'
# So we made b' p' our 328th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'is' + b'ual'
# So we made b'isual' our 329th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' token' + b's'
# So we made b' tokens' our 330th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'""' + b'"'
# So we made b'"""' our 331th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'd'
# So we made b' d' our 332th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' v' + b'isual'
# So we made b' visual' our 333th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'in' + b't'
# So we made b'int' our 334th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'co' + b'd'
# So we made b'cod' our 335th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'cod' + b'ing'
# So we made b'coding' our 336th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'str'
# So we made b' str' our 337th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'de' + b'code'
# So we made b'decode' our 338th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n' + b'\n   '
# So we made b'\n\n   ' our 339th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' visual' + b'ise'
# So we made b' visualise' our 340th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'"' + b')'
# So we made b'")' our 341th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' l' + b'i'
# So we made b' li' our 342th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'w' + b'ord'
# So we made b'word' our 343th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'n'
# So we made b' n' our 344th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'+'
# So we made b' +' our 345th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' pa' + b'ir'
# So we made b' pair' our 346th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'se' + b'l'
# So we made b'sel' our 347th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'sel' + b'f'
# So we made b'self' our 348th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'N'
# So we made b' N' our 349th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ou' + b'r'
# So we made b'our' our 350th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'at' + b'a'
# So we made b'ata' our 351th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'm' + b'p'
# So we made b'mp' our 352th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ab' + b'le'
# So we made b'able' our 353th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' in' + b't'
# So we made b' int' our 354th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'on' + b'e'
# So we made b'one' our 355th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'r' + b'n'
# So we made b'rn' our 356th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n' + b'\n       '
# So we made b'\n\n       ' our 357th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' li' + b'st'
# So we made b' list' our 358th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'l' + b'l'
# So we made b'll' our 359th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' word' + b's'
# So we made b' words' our 360th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'r' + b't'
# So we made b'rt' our 361th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'o'
# So we made b' o' our 362th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b't' + b'h'
# So we made b'th' our 363th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' N' + b'one'
# So we made b' None' our 364th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'u'
# So we made b' u' our 365th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' t' + b'o'
# So we made b' to' our 366th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' p' + b'r'
# So we made b' pr' our 367th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'(' + b'"'
# So we made b'("' our 368th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'l' + b'd'
# So we made b'ld' our 369th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'a' + b'c'
# So we made b'ac' our 370th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'token' + b's'
# So we made b'tokens' our 371th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' i' + b'f'
# So we made b' if' our 372th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'col' + b'or'
# So we made b'color' our 373th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n            ' + b'   '
# So we made b'\n               ' our 374th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'is'
# So we made b' is' our 375th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'de' + b'f'
# So we made b'def' our 376th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'pa' + b't'
# So we made b'pat' our 377th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ra' + b'in'
# So we made b'rain' our 378th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b's' + b'i'
# So we made b'si' our 379th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'rt' + b's'
# So we made b'rts' our 380th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' pr' + b'int'
# So we made b' print' our 381th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'n' + b'd'
# So we made b'nd' our 382th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b't' + b'u'
# So we made b'tu' our 383th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'-'
# So we made b' -' our 384th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
# ...
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' l' + b'ast'
# So we made b' last' our 560th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'h' + b'is'
# So we made b'his' our 561th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'at' + b'ion'
# So we made b'ation' our 562th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'm' + b'ent'
# So we made b'ment' our 563th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' b' + b'yte'
# So we made b' byte' our 564th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' en' + b'coding'
# So we made b' encoding' our 565th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'r' + b'o'
# So we made b'ro' our 566th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'mport'
# So we made b'import' our 567th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'k'
# So we made b'ik' our 568th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ik' + b'token'
# So we made b'iktoken' our 569th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' di' + b'ct'
# So we made b' dict' our 570th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'A'
# So we made b' A' our 571th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'te' + b'rn'
# So we made b'tern' our 572th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' u' + b'se'
# So we made b' use' our 573th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' in' + b'p'
# So we made b' inp' our 574th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' inp' + b'ut'
# So we made b' input' our 575th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' t' + b'ext'
# So we made b' text' our 576th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'decode' + b'r'
# So we made b'decoder' our 577th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' en' + b'code'
# So we made b' encode' our 578th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'|'
# So we made b' |' our 579th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'U'
# So we made b' U' our 580th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' [' + b']'
# So we made b' []' our 581th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'decode'
# So we made b' decode' our 582th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'De' + b'codes'
# So we made b'Decodes' our 583th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' re' + b'place'
# So we made b' replace' our 584th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'r' + b'or'
# So we made b'ror' our 585th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'c'
# So we made b'ic' our 586th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' s' + b'o'
# So we made b' so' our 587th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'a' + b'n'
# So we made b'an' our 588th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' wh' + b'ile'
# So we made b' while' our 589th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'me' + b'd'
# So we made b'med' our 590th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'ou'
# So we made b' ou' our 591th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ou' + b't'
# So we made b' out' our 592th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' e' + b'l'
# So we made b' el' our 593th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'f'
# So we made b'if' our 594th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'si' + b'mple'
# So we made b'simple' our 595th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' al' + b'l'
# So we made b' all' our 596th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' a' + b'nd'
# So we made b' and' our 597th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'er' + b'e'
# So we made b'ere' our 598th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b']' + b']'
# So we made b']]' our 599th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ir' + b'st'
# So we made b'irst' our 600th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# This is the sequence of merges performed in order to encode 'hello world':
# hello
# hello
# hello
# hello
# hello
#
#  world
#  world
#  world
#  world
#  world
#  world
#
# hello
# hello
# hello
# hello
# hello
#
#  world
#  world
#  world
#  world
#  world
#  world
#
#  aaaaaaaaaaaa
#  aaaaaaaaaaaa
#  aaaaaaaaaaaa
#  aaaaaaaaaaaa
#  aaaaaaaaaaaa
#  aaaaaaaaaaaa
#  aaaaaaaaaaaa
#  aaaaaaaaaaaa
#  aaaaaaaaaaaa
#  aaaaaaaaaaaa
#  aaaaaaaaaaaa
# [15339, 1917, 264, 70540, 33746]

# %%
import tiktoken

encoding = tiktoken.encoding_for_model("text-embedding-3-small")

print(encoding.encode("I love DataCamp"))
# Out:
# [40, 3021, 2956, 34955]

# %%
print(encoding.decode([40, 4048, 264, 2763, 505, 2956, 34955]))
# Out:
# I learn a lot from DataCamp
